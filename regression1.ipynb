# %% [markdown]
# # Problem Statement::

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# We have to determine whether the purity of oxygen is dependent on the amount of hydrocarbon present in the main condenser initially?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  ##Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
path = '/home/ashish/projects/linear_regression1_hydrocarbon_and_purity/reg2.xlsx'
data_frame = pd.read_excel(path)
data_frame
# Out:
#    Hydrocarbon level     O2
# 0               0.99  90.01
# 1               1.02  89.05
# 2               1.15  91.43
# 3               1.29  93.74
# 4               1.46  96.73
# 5               1.36  94.45
# 6               0.87  87.59
# 7               1.23  91.77
# 8               1.55  99.42
# 9               1.40  93.65

# %%
x_hydr = data_frame['Hydrocarbon level']
y_O2 = data_frame['O2']
sns.regplot(x=x_hydr,y=y_O2,fit_reg=True)
## Returns : ax : matplotlib Axes ----> The Axes object containing the plot.
plt.scatter(np.mean(x),np.mean(y),color="red")
plt.show()

# %%
import statsmodels.api as s
import statsmodels.regression.linear_model as sm

# %%
## statsmodels.regression.linear_model.OLS
t = s.add_constant(x_hydr)
model = sm.OLS(y_O2,t).fit()
model.summary()
# Out:
# /home/ashish/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     O2   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     100.6
# Date:                Tue, 28 Dec 2021   Prob (F-statistic):           8.30e-06
# Time:                        23:53:40   Log-Likelihood:                -13.382
# No. Observations:                  10   AIC:                             30.76
# Df Residuals:                       8   BIC:                             31.37
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
#     Regression equation ----> y = 73.6219 + (15.5537)*Hydrocarbon level
# ## R-squared = 92.6% ==> so this regression relationship is very strong.And, 92.6% of variability in the purity obtained OR O2 obtained can be explained by the Linear relationship between the percentage of hydrocarbon pre distillation and the percentage of purity or O2 obtained.
